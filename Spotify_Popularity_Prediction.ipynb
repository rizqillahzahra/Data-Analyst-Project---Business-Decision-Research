# %% [markdown]
# <a href="https://colab.research.google.com/github/rizqillahzahra/Data-Project/blob/master/Spotify_Popularity_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Dataframe
#
# Apa itu Dataframe?
# Dataframe adalah  tipe data menyerupai tabel atau yang setiap kolom dan barisnya berisikan value. Dataframe merupakan tipe data keluaran library Pandas dan umum digunakan oleh Data Scientist untuk melihat dan memanipulasi data.

# %%
import pandas as pd # import library

df = pd.read_csv('Spotify_dataset.csv')
df.head(5) # menampilkan n row awal dari suatu dataframe
# Out:
#    Index                   Title             Artist            Top Genre  \
# 0      1                 Sunrise        Norah Jones      adult standards
# 1      2             Black Night        Deep Purple           album rock
# 2      3          Clint Eastwood           Gorillaz  alternative hip hop
# 3      4           The Pretender       Foo Fighters    alternative metal
# 4      5  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0  2004                     157      30            53            -14
# 1  2000                     135      79            50            -11
# 2  2001                     168      69            66             -9
# 3  2007                     173      96            43             -4
# 4  2002                     106      82            58             -5
#
#    Liveness  Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %% [markdown]
# ## Operasi Sederhana pada DataFrame

# %%
df.shape
# Out:
# (1994, 15)

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
df.tail()
# Out:
#       Index             Title                    Artist        Top Genre  \
# 1989   1990  Heartbreak Hotel             Elvis Presley  adult standards
# 1990   1991         Hound Dog             Elvis Presley  adult standards
# 1991   1992   Johnny B. Goode               Chuck Berry       blues rock
# 1992   1993         Take Five  The Dave Brubeck Quartet            bebop
# 1993   1994    Blueberry Hill               Fats Domino  adult standards
#
#       Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 1989  1958                      94      21            70            -12
# 1990  1958                     175      76            36             -8
# 1991  1959                     168      80            53             -9
# 1992  1959                     174      26            45            -13
# 1993  1959                     133      50            49            -10
#
#       Liveness  Valence Length (Duration)  Acousticness  Speechiness  \
# ...

# %%
df.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# ...

# %% [markdown]
# ## Data Sorting

# %%
df.sort_values('Danceability', ascending=False)
# Out:
#       Index                                        Title  \
# 1477   1478                                Kingston Town
# 1752   1753                             Around the World
# 282     283                                 Watskeburt?!
# 192     193                          The Real Slim Shady
# 1264   1265                              Buffalo Soldier
# ...     ...                                          ...
# 1821   1822                             Run To The Water
# 360     361                                Belfast Child
# 1523   1524  Who Wants To Live Forever - Remastered 2011
# 662     663    Once Upon a Time in the West - Main Theme
# 1650   1651                    Live Forever - Remastered
#
#                          Artist           Top Genre  Year  \
# 1477                       UB40       reggae fusion  1989
# 1752                  Daft Punk             electro  1997
# 282   De Jeugd Van Tegenwoordig       dutch hip hop  2008
# ...

# %%
df.sort_values('Energy', ascending=True)
# Out:
#       Index                                   Title                   Artist  \
# 1978   1979     The First Time Ever I Saw Your Face            Roberta Flack
# 878     879                    Famous Blue Raincoat            Leonard Cohen
# 527     528                              I See Fire               Ed Sheeran
# 10       11                          Love Me Tender            Elvis Presley
# 228     229       Mad World (Feat. Michael Andrews)               Gary Jules
# ...     ...                                     ...                      ...
# 43       44                          American Idiot                Green Day
# 1648   1649  No Good (Start the Dance) [Remastered]              The Prodigy
# 186     187                        Go With The Flow  Queens of the Stone Age
# 1278   1279                          When Doves Cry                   Prince
# 1345   1346                          Angel Of Death                   Slayer
#
# ...

# %% [markdown]
# ## Data Filtering

# %%
df[df["Liveness"] > 34]
# Out:
#       Index                             Title           Artist  \
# 12       13                     Als Het Golft          De Dijk
# 13       14                    I'm going home  Ten Years After
# 18       19                             Music       John Miles
# 38       39                       All My Life     Foo Fighters
# 43       44                    American Idiot        Green Day
# ...     ...                               ...              ...
# 1950   1951                  Suspicious Minds    Elvis Presley
# 1951   1952  Whole Lotta Love - 1990 Remaster     Led Zeppelin
# 1968   1969                  Beautiful People          Melanie
# 1982   1983                         Get Ready       Rare Earth
# 1990   1991                         Hound Dog    Elvis Presley
#
#               Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 12          dutch indie  2000                     102      88            54
# ...

# %%
# Menampilkan baris yang memenuhi 2 kondisi yaitu province sama dengan Jawa Timur dan age lebih besar dari 40
df[ (df['Valence'] > 50) & (df['Speechiness'] < 50) ]
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# 6         7       She Will Be Loved                  Maroon 5
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...

# %% [markdown]
# ### Feature Engineering

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
df.Artist.nunique()
# Out:
# 731

# %%
# genderencoding = pd.get_dummies(df["Top Genre"])

# %%
# genderencoding.head()

# %%
# df = df.join(genderencoding)

# %%
df['db_upper_average'] = 0
df.loc[df['Loudness (dB)'] > df['Loudness (dB)'].mean(), "db_upper_average"] = 1

# %%
df['db_upper_average']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 1989    0
# 1990    1
# 1991    1
# 1992    0
# 1993    0
# Name: db_upper_average, Length: 1994, dtype: int64

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ![FinalProject.png](data:image/png;base64,...)

# %% [markdown]
# ## A. Problem
# Masalah apa yang ingin kita diselesaikan? Melanjutkan hands on kita semenjak day 1, sebagai contoh, kita dapat mengambil konteks dunia nyata dalam merumuskan permasalahan yang ingin kita pecahkan sebagai berikut:
#
# 1. Tingkat popularitas penyanyi/band ditentukan dari faktor apa saja
#
# ## B. Objective
# Apa yang bisa kita selesaikan? Dengan adanya project ini, kita akan melakukan analisis data terhadap data dan membangun model prediksi nilai siswa berdasarkan data-data tersebut.
#
# Maka rumusan permasalahan dapat terselesaikan karena dengan project ini...
#
# 1. Akan dibangunnya model prediksi nilai popularitas penyanyi/band dari beberapa faktor
# 2. Akan dilakukannya analisa terhadap korelasi antara faktor
#
# # C. Cleaning
# Kita sudah melakukan ini di hari-hari sebelumnya. Yuk, mulai load datanya!

# %%
df.shape
# Out:
# (1994, 16)

# %%
# mengecek missing value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1994 non-null   object
#  2   Artist                  1994 non-null   object
#  3   Top Genre               1994 non-null   object
#  4   Year                    1994 non-null   int64
#  5   Beats Per Minute (BPM)  1994 non-null   int64
#  6   Energy                  1994 non-null   int64
#  7   Danceability            1994 non-null   int64
#  8   Loudness (dB)           1994 non-null   int64
#  9   Liveness                1994 non-null   int64
#  10  Valence                 1994 non-null   int64
#  11  Length (Duration)       1994 non-null   object
#  12  Acousticness            1994 non-null   int64
#  13  Speechiness             1994 non-null   int64
# ...

# %%
df.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# ...

# %%
print(df.isnull().values.sum())
# Out:
# 0

# %% [markdown]
# ### **EDA recap: Apakah terdapat pola di dalam data kita?**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_top_5 = df.nlargest(5,["Popularity"])
df_top_5
# Out:
#       Index                            Title           Artist       Top Genre  \
# 793     794                     Dance Monkey      Tones and I  australian pop
# 787     788                         Memories         Maroon 5             pop
# 786     787                          bad guy    Billie Eilish      electropop
# 1641   1642  All I Want for Christmas Is You     Mariah Carey       dance pop
# 688     689                         Believer  Imagine Dragons     modern rock
#
#       Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 793   2019                      98      59            82             -6
# 787   2019                      91      32            76             -7
# 786   2019                     135      43            70            -11
# 1641  1994                     150      63            34             -7
# 688   2017                     125      78            78             -4
#
# ...

# %%
sns.displot(df_top_5, x="Popularity", discrete=True)
plt.title('Spotify Popularity')
plt.xlabel("Popularity")
plt.ylabel('Count')
# Out:
# Text(0.29999999999999716, 0.5, 'Count')

# %%
sns.jointplot(df['Popularity'], df['Danceability'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df['Popularity'], df['Liveness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df['Popularity'], df['Speechiness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df['Popularity'], df['Energy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df['Popularity'], df['Danceability'], kind='hex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# sns.pairplot(df)

# %%
sns.lmplot(x='Popularity', y='Danceability', data = df)

# %%
df = df.drop(columns=['Index','Year'])

# %%
# hanya memilih nilai korelasi di "upper triangle" -- menghindari duplikasi nilai
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# buat heatmap
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True, mask = mask)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ### Dari heatmap kita dapat melihat.... **Popularity** dan **Loudness** memiliki nilai korelasi yang tinggi diatas 0,17! Ini artinya semakin nilai tinggi nilai speechiness maka tinggi juga nilai popularity

# %%
sns.lmplot(x='Popularity', y='Loudness (dB)', data = df)

# %% [markdown]
# ## E. Model Building
# ### Yuk kita coba bikin model yang sesuai untuk menebak skor popularity sebuah lagu!

# %%
# import libraries yang dibutuhkan
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df.head()
# Out:
#                     Title             Artist            Top Genre  \
# 0                 Sunrise        Norah Jones      adult standards
# 1             Black Night        Deep Purple           album rock
# 2          Clint Eastwood           Gorillaz  alternative hip hop
# 3           The Pretender       Foo Fighters    alternative metal
# 4  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 0                     157      30            53            -14        11
# 1                     135      79            50            -11        17
# 2                     168      69            66             -9         7
# 3                     173      96            43             -4         3
# 4                     106      82            58             -5        10
#
#    Valence Length (Duration)  Acousticness  Speechiness  Popularity  \
# ...

# %%
x=df[[ 'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
       'Liveness', 'Valence', 'Acousticness',
       'Speechiness']]
y = df['Popularity']

# membagi data ke training dan testing data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print("X_train : ", x_train.shape)
print("X_test : ", x_test.shape)
print("Y_train : ", y_train.shape)
print("Y_test : ", y_test.shape)
# Out:
# X_train :  (1595, 8)
# X_test :  (399, 8)
# Y_train :  (1595,)
# Y_test :  (399,)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)

coeff_df = pd.DataFrame(lm.coef_,x.columns,columns=['Coefficient'])
coeff_df
# Out:
#                         Coefficient
# Beats Per Minute (BPM)     0.001289
# Energy                    -0.069737
# Danceability               0.073369
# Loudness (dB)              0.770440
# Liveness                  -0.110629
# Valence                    0.031200
# Acousticness              -0.014865
# Speechiness                0.321776

# %%
predictions = lm.predict(x_test)
plt.scatter(y_test, predictions)

# %% [markdown]
# ## Evaluasi Model

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 11.034475570975902
# MSE: 180.1124326777563
# RMSE: 13.420597329394704

# %%
sns.distplot((y_test-predictions), bins=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###  Sebagus apa sih model kita? Yuk bandingkan nilai prediksi model dengan score asli test set nya!

# %%
df_test_set = x_test
df_test_set = df_test_set.join(y_test)
df_test_set['PREDICTED SCORE'] = predictions
df_test_set.head(5)
# Out:
#       Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 1428                     153      74            45            -10        23
# 1347                     118      71            73             -9         8
# 1814                     150      79            34             -6        14
# 1981                      75      66            40            -10        17
# 1452                     119      65            32             -6        24
#
#       Valence  Acousticness  Speechiness  Popularity  PREDICTED SCORE
# 1428       94             2            6          40        58.638635
# 1347       85            63            3          65        61.134046
# 1814       43             0            4          56        59.351405
# 1981       51            77           12          50        58.867071
# 1452       47            50            3          83        58.094506

# %% [markdown]
# ## Mari kita visualisasikan perbandingan ini

# %%
# membandingkan hasil prediksi dan nilai asli
plt.figure(figsize=(8, 6))
plt.scatter(y_test, predictions)
plt.title("Results")
plt.xlabel("Actual Popularity")
plt.ylabel("Predicted Popularity")
# Out:
# Text(0, 0.5, 'Predicted Popularity')

# %%
plt.figure(figsize=(10, 6))

# mengurutkan nilai asli dari terkecil hingga tertinggi
y_sorted = np.sort(y_test.tolist())
y_sorted_index = np.argsort(y_test.tolist())

# merubah urutan prediction score berdasarkan urutan y_sorted 
predictions_sorted = predictions[y_sorted_index]

# plot kedua score
plt.scatter(np.arange(0,len(y_sorted)), y_sorted, label='popularity actual')
plt.scatter(np.arange(0,len(y_sorted)), predictions_sorted, label='popularity prediction')
plt.title("Perbandingan nilai asli dengan prediksi model")
plt.legend()

# %% [markdown]
# ### Okay... sekarang, coba bereksperimen yuk!
#
# #### 1. Gimana kalau kita coba pake variabel berbeda

# %%
x2 = df[['Danceability', 'Loudness (dB)',
       'Valence', 'Acousticness',
       'Speechiness']]
y2 = df['Popularity']

# membagi data ke training dan testing data
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2)

print("X_train : ", x2_train.shape)
print("X_test : ", x2_test.shape)
print("Y_train : ", y2_train.shape)
print("Y_test : ", y2_test.shape)
# Out:
# X_train :  (1595, 5)
# X_test :  (399, 5)
# Y_train :  (1595,)
# Y_test :  (399,)

# %%
lm = LinearRegression()
lm.fit(x2_train, y2_train)

coeff_df = pd.DataFrame(lm.coef_,x2.columns,columns=['Coefficient'])
coeff_df
# Out:
#                Coefficient
# Danceability      0.114611
# Loudness (dB)     0.590386
# Valence           0.003219
# Acousticness     -0.001203
# Speechiness       0.244861

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 11.034475570975902
# MSE: 180.1124326777563
# RMSE: 13.420597329394704

# %%
df2_test_set = x2_test
df2_test_set = df2_test_set.join(y2_test)
df2_test_set['PREDICTED SCORE'] = predictions
df2_test_set.head(5)
# Out:
#       Danceability  Loudness (dB)  Valence  Acousticness  Speechiness  \
# 1720            64             -6       72             0            4
# 686             49             -6       19             3            5
# 1213            38            -13       74             2            4
# 1163            44             -8       78             1            4
# 1121            48             -5       94             1            4
#
#       Popularity  PREDICTED SCORE
# 1720          67        58.638635
# 686           76        61.134046
# 1213          70        59.351405
# 1163          39        58.867071
# 1121          42        58.094506

# %% [markdown]
# ### Model ketiga

# %%
x3 = df[['Danceability','Loudness (dB)','Speechiness']]
y3 = df['Popularity']

# membagi data ke training dan testing data
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.2)

print("X_train : ", x3_train.shape)
print("X_test : ", x3_test.shape)
print("Y_train : ", y3_train.shape)
print("Y_test : ", y3_test.shape)
# Out:
# X_train :  (1595, 3)
# X_test :  (399, 3)
# Y_train :  (1595,)
# Y_test :  (399,)

# %%
lm = LinearRegression()
lm.fit(x3_train, y3_train)

coeff_df = pd.DataFrame(lm.coef_,x3.columns,columns=['Coefficient'])
coeff_df
# Out:
#                Coefficient
# Danceability      0.137403
# Loudness (dB)     0.572456
# Speechiness       0.244687

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 11.034475570975902
# MSE: 180.1124326777563
# RMSE: 13.420597329394704

# %%
df3_test_set = x3_test
df3_test_set = df3_test_set.join(y3_test)
df3_test_set['PREDICTED SCORE'] = predictions
df3_test_set.head(5)
# Out:
#       Danceability  Loudness (dB)  Speechiness  Popularity  PREDICTED SCORE
# 1325            44            -18            4          50        58.638635
# 1892            40             -8            3          71        61.134046
# 844             45            -11            4          71        59.351405
# 1486            71             -5            5          73        58.867071
# 1112            47            -13            3          75        58.094506

# %%
plt.figure(figsize=(10, 6))

# mengurutkan nilai asli dari terkecil hingga tertinggi
y_sorted = np.sort(y_test.tolist())
y_sorted_index = np.argsort(y_test.tolist())

# merubah urutan prediction score berdasarkan urutan y_sorted 
predictions_sorted = predictions[y_sorted_index]

# plot kedua score
plt.scatter(np.arange(0,len(y_sorted)), y_sorted, label='popularity actual')
plt.scatter(np.arange(0,len(y_sorted)), predictions_sorted, label='popularity prediction')
plt.title("Perbandingan nilai asli dengan prediksi model")
plt.legend()
